# %% [markdown]
# ## Explanation 1 - import and clear the data

# %% [markdown]
# In this and the next document an explanation on how to import and clear the data and how to perform distribution fitting with Python is provided.
#
# The *Colorado River case study* is taken as a reference.
#
# This first document focuses on importing and clearing the data.

# %% [markdown]
# To start with, we need to import all libraries we will need.

# %%
import datetime

import numpy as np
import pandas as pd

# %% [markdown]
# Once libraries are imported, we need to load the file. For convenience, we store it into a Pandas DataFrame.

# %%
# df = pd.read_csv('Colorado river.txt')

# %% [markdown]
# Try uncommenting the code and then run it.
#
# As you can see, it seems that we need to add some arguments in the `pd.read_csv` line otherwise we will not be able to load the file.
#
# If you look at the *.txt* file you can see that we can get rid of the first 49 rows (as they don't contain any data). That's what the argument `skiprows` does. At the same time we can set the first row (i.e., the index is 0) as the `header` of the columns, which represents the name of each of them.
# On top of that we also need to define the delimiter between columns, through the `sep` argument, which in this case is a tab space.

# %%
df = pd.read_csv('Colorado river.txt', skiprows = 49, header = 0,  sep='\t')
df
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3505: DtypeWarning: Columns (1,3,5,7,9,11,12,13,14,15,17,19,21,23,25,27,29,31,33,35,37,39,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       agency_cd   site_no    datetime 142739_00010_00003  \
# 0            5s       15s         20d                14n
# 1          USGS  09180500  1949-05-01                NaN
# 2          USGS  09180500  1949-05-02                NaN
# 3          USGS  09180500  1949-05-03                NaN
# 4          USGS  09180500  1949-05-04                NaN
# ...         ...       ...         ...                ...
# 27040      USGS   9180500  2023-05-12               11.4
# 27041      USGS   9180500  2023-05-13               11.7
# 27042      USGS   9180500  2023-05-14               11.9
# 27043      USGS   9180500  2023-05-15               12.2
# 27044      USGS   9180500  2023-05-16               12.6
#
#       142739_00010_00003_cd 142740_00010_00011 142740_00010_00011_cd  \
# 0                       10s                14n                   10s
# 1                       NaN               11.1                     A
# 2                       NaN               12.8                     A
# 3                       NaN               14.4                     A
# 4                       NaN               13.3                     A
# ...                     ...                ...                   ...
# 27040                     P                NaN                   NaN
# 27041                     P                NaN                   NaN
# 27042                     P                NaN                   NaN
# 27043                     P                NaN                   NaN
# 27044                     P                NaN                   NaN
#
#       142741_00060_00003 142741_00060_00003_cd 142743_00095_00003  ...  \
# 0                    14n                   10s                14n  ...
# 1                  24200                     A                NaN  ...
# 2                  21200                     A                NaN  ...
# 3                  19700                     A                NaN  ...
# 4                  23300                     A                NaN  ...
# ...                  ...                   ...                ...  ...
# 27040              30300                     P              341.0  ...
# 27041              30600                     P              339.0  ...
# 27042              32300                     P              335.0  ...
# 27043              33700                     P              329.0  ...
# 27044              35000                     P              332.0  ...
#
#       308125_00300_00002 308125_00300_00002_cd 314970_63680_00002  \
# 0                    14n                   10s                14n
# 1                    NaN                   NaN                NaN
# 2                    NaN                   NaN                NaN
# 3                    NaN                   NaN                NaN
# 4                    NaN                   NaN                NaN
# ...                  ...                   ...                ...
# 27040                9.7                     P              762.0
# 27041                9.6                     P              690.0
# 27042                9.7                     P              698.0
# 27043                9.6                     P              648.0
# 27044                9.3                     P              652.0
#
#       314970_63680_00002_cd 314971_63680_00003 314971_63680_00003_cd  \
# 0                       10s                14n                   10s
# 1                       NaN                NaN                   NaN
# 2                       NaN                NaN                   NaN
# 3                       NaN                NaN                   NaN
# 4                       NaN                NaN                   NaN
# ...                     ...                ...                   ...
# 27040                     P              843.0                     P
# 27041                     P              763.0                     P
# 27042                     P              754.0                     P
# 27043                     P              712.0                     P
# 27044                     P              713.0                     P
#
#       314972_63680_00001 314972_63680_00001_cd 322444_00045_00006  \
# 0                    14n                   10s                14n
# 1                    NaN                   NaN                NaN
# 2                    NaN                   NaN                NaN
# 3                    NaN                   NaN                NaN
# 4                    NaN                   NaN                NaN
# ...                  ...                   ...                ...
# 27040              956.0                     P                0.0
# 27041              857.0                     P                0.0
# 27042              869.0                     P                0.0
# 27043              784.0                     P                0.0
# 27044              767.0                     P                0.0
#
#       322444_00045_00006_cd
# 0                       10s
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 27040                     P
# 27041                     P
# 27042                     P
# 27043                     P
# 27044                     P
#
# [27045 rows x 43 columns]

# %% [markdown]
# We can also drop the first row (i.e., row 0) which does not contain any data.
# \
# The `inplace = True` argument will delete the row (or column) directly from the original DataFrame.

# %%
df.drop([0], axis = 0, inplace = True)
df
# Out:
#       agency_cd   site_no    datetime 142739_00010_00003  \
# 1          USGS  09180500  1949-05-01                NaN
# 2          USGS  09180500  1949-05-02                NaN
# 3          USGS  09180500  1949-05-03                NaN
# 4          USGS  09180500  1949-05-04                NaN
# 5          USGS  09180500  1949-05-05                NaN
# ...         ...       ...         ...                ...
# 27040      USGS   9180500  2023-05-12               11.4
# 27041      USGS   9180500  2023-05-13               11.7
# 27042      USGS   9180500  2023-05-14               11.9
# 27043      USGS   9180500  2023-05-15               12.2
# 27044      USGS   9180500  2023-05-16               12.6
#
#       142739_00010_00003_cd 142740_00010_00011 142740_00010_00011_cd  \
# 1                       NaN               11.1                     A
# 2                       NaN               12.8                     A
# 3                       NaN               14.4                     A
# 4                       NaN               13.3                     A
# 5                       NaN               12.2                     A
# ...                     ...                ...                   ...
# 27040                     P                NaN                   NaN
# 27041                     P                NaN                   NaN
# 27042                     P                NaN                   NaN
# 27043                     P                NaN                   NaN
# 27044                     P                NaN                   NaN
#
#       142741_00060_00003 142741_00060_00003_cd 142743_00095_00003  ...  \
# 1                  24200                     A                NaN  ...
# 2                  21200                     A                NaN  ...
# 3                  19700                     A                NaN  ...
# 4                  23300                     A                NaN  ...
# 5                  24600                     A                NaN  ...
# ...                  ...                   ...                ...  ...
# 27040              30300                     P              341.0  ...
# 27041              30600                     P              339.0  ...
# 27042              32300                     P              335.0  ...
# 27043              33700                     P              329.0  ...
# 27044              35000                     P              332.0  ...
#
#       308125_00300_00002 308125_00300_00002_cd 314970_63680_00002  \
# 1                    NaN                   NaN                NaN
# 2                    NaN                   NaN                NaN
# 3                    NaN                   NaN                NaN
# 4                    NaN                   NaN                NaN
# 5                    NaN                   NaN                NaN
# ...                  ...                   ...                ...
# 27040                9.7                     P              762.0
# 27041                9.6                     P              690.0
# 27042                9.7                     P              698.0
# 27043                9.6                     P              648.0
# 27044                9.3                     P              652.0
#
#       314970_63680_00002_cd 314971_63680_00003 314971_63680_00003_cd  \
# 1                       NaN                NaN                   NaN
# 2                       NaN                NaN                   NaN
# 3                       NaN                NaN                   NaN
# 4                       NaN                NaN                   NaN
# 5                       NaN                NaN                   NaN
# ...                     ...                ...                   ...
# 27040                     P              843.0                     P
# 27041                     P              763.0                     P
# 27042                     P              754.0                     P
# 27043                     P              712.0                     P
# 27044                     P              713.0                     P
#
#       314972_63680_00001 314972_63680_00001_cd 322444_00045_00006  \
# 1                    NaN                   NaN                NaN
# 2                    NaN                   NaN                NaN
# 3                    NaN                   NaN                NaN
# 4                    NaN                   NaN                NaN
# 5                    NaN                   NaN                NaN
# ...                  ...                   ...                ...
# 27040              956.0                     P                0.0
# 27041              857.0                     P                0.0
# 27042              869.0                     P                0.0
# 27043              784.0                     P                0.0
# 27044              767.0                     P                0.0
#
#       322444_00045_00006_cd
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# ...                     ...
# 27040                     P
# 27041                     P
# 27042                     P
# 27043                     P
# 27044                     P
#
# [27044 rows x 43 columns]

# %% [markdown]
# As you can see, now data have been imported and stored in a proper DataFrame.
# \
# However, we don't need all columns for our analysis. So we can drop some of them.
#
# There are two ways of dropping an unnecessary column:
# 1) by specifying the name of the column;
# 2) by specifying the number of the column in the DataFrame.
#
# Remember that `axis = 0` is for rows, while `axis = 1` is for columns.

# %% [markdown]
# 1. Specify the name: we will drop the two columns *agency_cd* and *site_no*.

# %%
df.drop(['agency_cd', 'site_no'], axis = 1, inplace = True)
df
# Out:
#          datetime 142739_00010_00003 142739_00010_00003_cd 142740_00010_00011  \
# 1      1949-05-01                NaN                   NaN               11.1
# 2      1949-05-02                NaN                   NaN               12.8
# 3      1949-05-03                NaN                   NaN               14.4
# 4      1949-05-04                NaN                   NaN               13.3
# 5      1949-05-05                NaN                   NaN               12.2
# ...           ...                ...                   ...                ...
# 27040  2023-05-12               11.4                     P                NaN
# 27041  2023-05-13               11.7                     P                NaN
# 27042  2023-05-14               11.9                     P                NaN
# 27043  2023-05-15               12.2                     P                NaN
# 27044  2023-05-16               12.6                     P                NaN
#
#       142740_00010_00011_cd 142741_00060_00003 142741_00060_00003_cd  \
# 1                         A              24200                     A
# 2                         A              21200                     A
# 3                         A              19700                     A
# 4                         A              23300                     A
# 5                         A              24600                     A
# ...                     ...                ...                   ...
# 27040                   NaN              30300                     P
# 27041                   NaN              30600                     P
# 27042                   NaN              32300                     P
# 27043                   NaN              33700                     P
# 27044                   NaN              35000                     P
#
#       142743_00095_00003 142743_00095_00003_cd 142744_80154_00003  ...  \
# 1                    NaN                   NaN               2200  ...
# 2                    NaN                   NaN                900  ...
# 3                    NaN                   NaN                500  ...
# 4                    NaN                   NaN               3200  ...
# 5                    NaN                   NaN               8100  ...
# ...                  ...                   ...                ...  ...
# 27040              341.0                     P                NaN  ...
# 27041              339.0                     P                NaN  ...
# 27042              335.0                     P                NaN  ...
# 27043              329.0                     P                NaN  ...
# 27044              332.0                     P                NaN  ...
#
#       308125_00300_00002 308125_00300_00002_cd 314970_63680_00002  \
# 1                    NaN                   NaN                NaN
# 2                    NaN                   NaN                NaN
# 3                    NaN                   NaN                NaN
# 4                    NaN                   NaN                NaN
# 5                    NaN                   NaN                NaN
# ...                  ...                   ...                ...
# 27040                9.7                     P              762.0
# 27041                9.6                     P              690.0
# 27042                9.7                     P              698.0
# 27043                9.6                     P              648.0
# 27044                9.3                     P              652.0
#
#       314970_63680_00002_cd 314971_63680_00003 314971_63680_00003_cd  \
# 1                       NaN                NaN                   NaN
# 2                       NaN                NaN                   NaN
# 3                       NaN                NaN                   NaN
# 4                       NaN                NaN                   NaN
# 5                       NaN                NaN                   NaN
# ...                     ...                ...                   ...
# 27040                     P              843.0                     P
# 27041                     P              763.0                     P
# 27042                     P              754.0                     P
# 27043                     P              712.0                     P
# 27044                     P              713.0                     P
#
#       314972_63680_00001 314972_63680_00001_cd 322444_00045_00006  \
# 1                    NaN                   NaN                NaN
# 2                    NaN                   NaN                NaN
# 3                    NaN                   NaN                NaN
# 4                    NaN                   NaN                NaN
# 5                    NaN                   NaN                NaN
# ...                  ...                   ...                ...
# 27040              956.0                     P                0.0
# 27041              857.0                     P                0.0
# 27042              869.0                     P                0.0
# 27043              784.0                     P                0.0
# 27044              767.0                     P                0.0
#
#       322444_00045_00006_cd
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# ...                     ...
# 27040                     P
# 27041                     P
# 27042                     P
# 27043                     P
# 27044                     P
#
# [27044 rows x 41 columns]

# %% [markdown]
# 2. Specify the number: we are not interested in columns 13 onwards for our analysis.

# %%
df.drop(df.columns[12:], axis = 1, inplace = True)
df
# Out:
#          datetime 142739_00010_00003 142739_00010_00003_cd 142740_00010_00011  \
# 1      1949-05-01                NaN                   NaN               11.1
# 2      1949-05-02                NaN                   NaN               12.8
# 3      1949-05-03                NaN                   NaN               14.4
# 4      1949-05-04                NaN                   NaN               13.3
# 5      1949-05-05                NaN                   NaN               12.2
# ...           ...                ...                   ...                ...
# 27040  2023-05-12               11.4                     P                NaN
# 27041  2023-05-13               11.7                     P                NaN
# 27042  2023-05-14               11.9                     P                NaN
# 27043  2023-05-15               12.2                     P                NaN
# 27044  2023-05-16               12.6                     P                NaN
#
#       142740_00010_00011_cd 142741_00060_00003 142741_00060_00003_cd  \
# 1                         A              24200                     A
# 2                         A              21200                     A
# 3                         A              19700                     A
# 4                         A              23300                     A
# 5                         A              24600                     A
# ...                     ...                ...                   ...
# 27040                   NaN              30300                     P
# 27041                   NaN              30600                     P
# 27042                   NaN              32300                     P
# 27043                   NaN              33700                     P
# 27044                   NaN              35000                     P
#
#       142743_00095_00003 142743_00095_00003_cd 142744_80154_00003  \
# 1                    NaN                   NaN               2200
# 2                    NaN                   NaN                900
# 3                    NaN                   NaN                500
# 4                    NaN                   NaN               3200
# 5                    NaN                   NaN               8100
# ...                  ...                   ...                ...
# 27040              341.0                     P                NaN
# 27041              339.0                     P                NaN
# 27042              335.0                     P                NaN
# 27043              329.0                     P                NaN
# 27044              332.0                     P                NaN
#
#       142744_80154_00003_cd 142745_80155_00003
# 1                         A             144000
# 2                         A              51500
# 3                         A              26600
# 4                         A             201000
# 5                         A             547000
# ...                     ...                ...
# 27040                   NaN                NaN
# 27041                   NaN                NaN
# 27042                   NaN                NaN
# 27043                   NaN                NaN
# 27044                   NaN                NaN
#
# [27044 rows x 12 columns]

# %% [markdown]
# We keep dropping unnecessary columns.

# %%
df.drop(df.columns[1:3], axis = 1, inplace = True)
df
# Out:
#          datetime 142740_00010_00011 142740_00010_00011_cd 142741_00060_00003  \
# 1      1949-05-01               11.1                     A              24200
# 2      1949-05-02               12.8                     A              21200
# 3      1949-05-03               14.4                     A              19700
# 4      1949-05-04               13.3                     A              23300
# 5      1949-05-05               12.2                     A              24600
# ...           ...                ...                   ...                ...
# 27040  2023-05-12                NaN                   NaN              30300
# 27041  2023-05-13                NaN                   NaN              30600
# 27042  2023-05-14                NaN                   NaN              32300
# 27043  2023-05-15                NaN                   NaN              33700
# 27044  2023-05-16                NaN                   NaN              35000
#
#       142741_00060_00003_cd 142743_00095_00003 142743_00095_00003_cd  \
# 1                         A                NaN                   NaN
# 2                         A                NaN                   NaN
# 3                         A                NaN                   NaN
# 4                         A                NaN                   NaN
# 5                         A                NaN                   NaN
# ...                     ...                ...                   ...
# 27040                     P              341.0                     P
# 27041                     P              339.0                     P
# 27042                     P              335.0                     P
# 27043                     P              329.0                     P
# 27044                     P              332.0                     P
#
#       142744_80154_00003 142744_80154_00003_cd 142745_80155_00003
# 1                   2200                     A             144000
# 2                    900                     A              51500
# 3                    500                     A              26600
# 4                   3200                     A             201000
# 5                   8100                     A             547000
# ...                  ...                   ...                ...
# 27040                NaN                   NaN                NaN
# 27041                NaN                   NaN                NaN
# 27042                NaN                   NaN                NaN
# 27043                NaN                   NaN                NaN
# 27044                NaN                   NaN                NaN
#
# [27044 rows x 10 columns]

# %%
df.drop(df.columns[1:3], axis = 1, inplace = True)
df
# Out:
#          datetime 142741_00060_00003 142741_00060_00003_cd 142743_00095_00003  \
# 1      1949-05-01              24200                     A                NaN
# 2      1949-05-02              21200                     A                NaN
# 3      1949-05-03              19700                     A                NaN
# 4      1949-05-04              23300                     A                NaN
# 5      1949-05-05              24600                     A                NaN
# ...           ...                ...                   ...                ...
# 27040  2023-05-12              30300                     P              341.0
# 27041  2023-05-13              30600                     P              339.0
# 27042  2023-05-14              32300                     P              335.0
# 27043  2023-05-15              33700                     P              329.0
# 27044  2023-05-16              35000                     P              332.0
#
#       142743_00095_00003_cd 142744_80154_00003 142744_80154_00003_cd  \
# 1                       NaN               2200                     A
# 2                       NaN                900                     A
# 3                       NaN                500                     A
# 4                       NaN               3200                     A
# 5                       NaN               8100                     A
# ...                     ...                ...                   ...
# 27040                     P                NaN                   NaN
# 27041                     P                NaN                   NaN
# 27042                     P                NaN                   NaN
# 27043                     P                NaN                   NaN
# 27044                     P                NaN                   NaN
#
#       142745_80155_00003
# 1                 144000
# 2                  51500
# 3                  26600
# 4                 201000
# 5                 547000
# ...                  ...
# 27040                NaN
# 27041                NaN
# 27042                NaN
# 27043                NaN
# 27044                NaN
#
# [27044 rows x 8 columns]

# %% [markdown]
# The line `drop(df.columns[1:3])` is repeated twice because once you drop those columns their place will be "taken" by the next ones (every column will shift to the left by the same amount of places of the dropped columns).

# %%
df.drop(df.columns[2:7], axis = 1, inplace = True)
df
# Out:
#          datetime 142741_00060_00003 142745_80155_00003
# 1      1949-05-01              24200             144000
# 2      1949-05-02              21200              51500
# 3      1949-05-03              19700              26600
# 4      1949-05-04              23300             201000
# 5      1949-05-05              24600             547000
# ...           ...                ...                ...
# 27040  2023-05-12              30300                NaN
# 27041  2023-05-13              30600                NaN
# 27042  2023-05-14              32300                NaN
# 27043  2023-05-15              33700                NaN
# 27044  2023-05-16              35000                NaN
#
# [27044 rows x 3 columns]

# %% [markdown]
# Now we have deleted all unnecessary columns and we are left with only those three we need (date of record, water discharge, and suspended sediment discharge respectively).

# %% [markdown]
# For better referencing the columns, we can rename them.

# %%
df.rename(columns = {'datetime': 'Date', '142741_00060_00003': r'Discharge $(m^{3} s^{-1})$',
                     '142745_80155_00003': r'Suspended sediment discharge $(ton day^{-1})$'}, inplace = True)

df
# Out:
#              Date Discharge $(m^{3} s^{-1})$  \
# 1      1949-05-01                      24200
# 2      1949-05-02                      21200
# 3      1949-05-03                      19700
# 4      1949-05-04                      23300
# 5      1949-05-05                      24600
# ...           ...                        ...
# 27040  2023-05-12                      30300
# 27041  2023-05-13                      30600
# 27042  2023-05-14                      32300
# 27043  2023-05-15                      33700
# 27044  2023-05-16                      35000
#
#       Suspended sediment discharge $(ton day^{-1})$
# 1                                            144000
# 2                                             51500
# 3                                             26600
# 4                                            201000
# 5                                            547000
# ...                                             ...
# 27040                                           NaN
# 27041                                           NaN
# 27042                                           NaN
# 27043                                           NaN
# 27044                                           NaN
#
# [27044 rows x 3 columns]

# %% [markdown]
# We create an array where we store the names of the columns because we will need to reference them later on.

# %%
col = df.columns.values

# %% [markdown]
# We can also change the data type of the columns. For instance, we want the first column (*Date*) to be in datetime format, while the second and third ones to be integer and float, respectively.
#
# We take advantage of these lines to convert US units to SI units for water and suspended sediment discharge records.

# %%
df[col[1]] = df[col[1]].astype('int') * 0.0283168
df[col[2]] = df[col[2]].astype('float') * 0.91
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
#             Date  Discharge $(m^{3} s^{-1})$  \
# 1     1949-05-01                   685.26656
# 2     1949-05-02                   600.31616
# 3     1949-05-03                   557.84096
# 4     1949-05-04                   659.78144
# 5     1949-05-05                   696.59328
# ...          ...                         ...
# 27040 2023-05-12                   857.99904
# 27041 2023-05-13                   866.49408
# 27042 2023-05-14                   914.63264
# 27043 2023-05-15                   954.27616
# 27044 2023-05-16                   991.08800
#
#        Suspended sediment discharge $(ton day^{-1})$
# 1                                           131040.0
# 2                                            46865.0
# 3                                            24206.0
# 4                                           182910.0
# 5                                           497770.0
# ...                                              ...
# 27040                                            NaN
# 27041                                            NaN
# 27042                                            NaN
# 27043                                            NaN
# 27044                                            NaN
#
# [27044 rows x 3 columns]

# %% [markdown]
# Now the DataFrame is ready to use!
#
# We can also store each column into a single array.
# \
# Let's start with `numpy.array`.

# %%
date_numpy = np.array(df[col[0]])

# %% [markdown]
# You can also choose a different type of array, like a list for instance.

# %%
date_list = [df[col[0]]]

# %% [markdown]
# You can print the `type` of both *date* arrays to check their data type.
#
# Can you think of any other data type?

# %%
print(type(date_numpy))
print(type(date_list))
# Out:
# <class 'numpy.ndarray'>
# <class 'list'>

# %% [markdown]
# We can repeat the same procedure for the water discharge (it will be done only using `numpy.array`).

# %%
water_discharge = np.array(df[col[1]])

# %% [markdown]
# _Exercise_
#
# Get suspended sediment discharge data from the DataFrame column into a single array.

# %%
# use this code space for the exercise
